# %% [markdown]
# <a href="https://colab.research.google.com/github/SYM19/tumor-drug-penetration-model/blob/main/Tumor_Drug_Simulation_Core.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

class TumorModel:
    def __init__(self, grid_size=100):
        self.size = grid_size
        self.concentration = np.zeros((grid_size, grid_size))

    def set_source(self):
        self.concentration[:, 0] = 1.0

    def run_step(self, D, k):
        # D是扩散系数，k是消耗率。
        # 还没写数学公式。
        pass

    def display(self):
        # 绘图函数。用热力图展示当前的药物分布。
        plt.imshow(self.concentration, cmap='magma')
        plt.title("Current Drug Concentration")
        plt.show()

# 实例化对象并运行测试
model = TumorModel()
model.set_source()
model.display()

# %% [markdown]
# # 项目名称：基于 PDE 的肿瘤药物渗透模拟
#
# ## 第一阶段：模型框架与环境测试
